# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
os.chdir("C:\\Users\\sophi_1kw7ru0\\Documents\\BMI312 final");

# %%
data = pd.read_csv("C:\\Users\\sophi_1kw7ru0\\Documents\\BMI312 final\\adult19.csv")

# %%
data.head()
# Out:
#    URBRRL  RATCAT_A  INCGRP_A  INCTCFLG_A  FAMINCTC_A  IMPINCFLG_A  PPSU  \
# 0       4         9         3           0       60000            2     2
# 1       4         9         3           0       50000            0     2
# 2       4        12         3           0       65000            1     2
# 3       4        14         5           0      120000            0     2
# 4       1         4         1           0       30000            0     2
#
#    PSTRAT  HISPALLP_A  RACEALLP_A  ...  PROXYREL_A  PROXY_A  AVAIL_A  \
# 0     122           3           2  ...         NaN      NaN        1
# 1     122           2           1  ...         NaN      NaN        1
# 2     122           2           1  ...         NaN      NaN        1
# 3     122           1           8  ...         NaN      NaN        1
# 4     115           2           1  ...         NaN      NaN        1
#
#    HHSTAT_A  INTV_QRT  RECTYPE     WTFA_A    WTIA_A      HHX  POVRATTC_A
# ...

# %%
data.shape
# Out:
# (31997, 534)

# %%
data["DIFF_A"].describe()
# Out:
# count    31997.000000
# mean         1.304591
# std          0.653480
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          9.000000
# Name: DIFF_A, dtype: float64

# %%
data["DIFF_A"].plot(kind='hist')
# Out:
# <img src="data:image/png;base64,..." width="871.9333333333334">
# <AxesSubplot:ylabel='Frequency'>

# %%
data["EDUC_A"].describe()
# Out:
# count    31997.000000
# mean         6.352721
# std          7.330429
# min          0.000000
# 25%          4.000000
# 50%          5.000000
# 75%          8.000000
# max         99.000000
# Name: EDUC_A, dtype: float64

# %%
data["EDUC_A"].plot(kind='hist',bins=100)
# Out:
# <img src="data:image/png;base64,..." width="871.9333333333334">
# <AxesSubplot:ylabel='Frequency'>

# %%
data["FAMINCTC_A"].describe()
# Out:
# count     31997.000000
# mean      73261.058037
# std       56695.574745
# min           0.000000
# 25%       30000.000000
# 50%       60000.000000
# 75%      100000.000000
# max      220000.000000
# Name: FAMINCTC_A, dtype: float64

# %%
data["FAMINCTC_A"].plot(kind='hist',bins=40)
# Out:
# <img src="data:image/png;base64,..." width="871.9333333333334">
# <AxesSubplot:ylabel='Frequency'>

# %%
data["PAIFRQ3M_A"].describe()
# Out:
# count    31840.000000
# mean         2.091771
# std          1.276890
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          9.000000
# Name: PAIFRQ3M_A, dtype: float64

# %%
data["PAIFRQ3M_A"].plot(kind='hist')
# Out:
# <img src="data:image/png;base64,..." width="871.9333333333334">
# <AxesSubplot:ylabel='Frequency'>

# %%
data["DEPFREQ_A"].describe()
# Out:
# count    31997.000000
# mean         4.325468
# std          1.204813
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          9.000000
# Name: DEPFREQ_A, dtype: float64

# %%
data["DEPFREQ_A"].plot(kind='hist')
# Out:
# <img src="data:image/png;base64,..." width="871.9333333333334">
# <AxesSubplot:ylabel='Frequency'>

# %%
#remove nan from dataset
data_clean = data.dropna(axis=0, subset = ["DIFF_A","PAIFRQ3M_A","EDUC_A","FAMINCTC_A"])

# %%
data_clean.shape
# Out:
# (31840, 534)
